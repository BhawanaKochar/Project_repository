# %% [markdown]
# # Simple Linear Regression

# %%
# Install all the libraries before importing them
import numpy as np

import pandas as pd 
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6920/3572771746.py in <module>
#       2 import numpy as np
#       3
# ----> 4 import pandas as pd
#       5 import matplotlib.pyplot as plt
#       6 from mpl_toolkits.mplot3d import Axes3D
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ### Generate random input data to train on

# %%
# First, we should declare a variable containing the size of the training set we want to generate.
observations = 10000

# We will work with two variables as inputs. You can think about them as x1 and x2 in our previous examples.
xs = np.random.uniform(low=-10, high=10, size=(observations,1))
zs = np.random.uniform(-10, 10, (observations,1))

# Combine the two dimensions of the input into one input matrix. 
inputs = np.column_stack((xs,zs))

# Check if the dimensions of the inputs are the same as the ones we defined in the linear model lectures. 
print (inputs.shape)
print(inputs)
# Out:
# (10000, 2)
# [[ 6.79878915 -0.96981942]
#  [-2.03382369 -5.74996252]
#  [ 2.7158628   3.3551302 ]
#  ...
#  [-4.47946204 -6.64195255]
#  [ 8.37681855 -0.23178682]
#  [ 8.74619289 -2.05427159]]

# %%
# We want to "make up" a function, use the ML methodology, and see if the algorithm has learned it.
noise = np.random.uniform(-1, 1, (observations,1))

# Produce the targets according to the f(x,z)
targets = []
for x in range(len(inputs)):
    targets.append(13*inputs[x][0]-8*inputs[x][1]+np.random.uniform(-5,5))

targets = np.reshape(targets, [10000,1])

targets.shape
# Out:
# (10000, 1)

# %% [markdown]
# ### Initialize variables

# %%
# We will initialize the weights and biases randomly in some small initial range.
init_range = 0.5

# Weights are of size k x m, where k is the number of input variables and m is the number of output variables
weights = np.random.uniform(low=-init_range, high=init_range, size=(2, 1))

# Biases are of size 1 since there is only 1 output. The bias is a scalar.
biases = np.random.uniform(low=-init_range, high=init_range, size=1)

#Print the weights to get a sense of how they were initialized.
print (weights)
print (biases)
# Out:
# [[-0.03256099]
#  [-0.09316746]]
# [0.15260832]

# %%
learning_rate = 0.02

# %% [markdown]
# ### Train the model

# %%
# We iterate over our training dataset 100 times. That works well with a learning rate of 0.02.
for i in range (10000):
    outputs = np.dot(inputs,weights) + biases
    deltas = outputs - targets
    loss = (np.sum(deltas ** 2)) / (2 * observations)
    print (weights)
    deltas_scaled = deltas / observations
    weights = weights - learning_rate * np.dot(inputs.T,deltas_scaled)
    biases = biases - learning_rate * np.sum(deltas_scaled)
# Out:
# [[-0.24569348]
#  [-0.15381234]]
# [[ 4.15364502]
#  [-2.79455022]]
# [[ 7.09155148]
#  [-4.5457312 ]]
# [[ 9.05351661]
#  [-5.70699018]]
# [[10.36374599]
#  [-6.47704093]]
# [[11.2387421 ]
#  [-6.98766551]]
# [[11.82308484]
#  [-7.326257  ]]
# [[12.21332499]
#  [-7.55077036]]
# [[12.47393978]
#  [-7.69963787]]
# [[12.64798776]
#  [-7.79834512]]
# [[12.76422409]
#  [-7.86379204]]
# [[12.841852  ]
#  [-7.90718507]]
# [[12.89369583]
#  [-7.93595512]]
# [[12.92832004]
#  [-7.9550295 ]]
# [[12.95144424]
#  [-7.96767535]]
# [[12.96688818]
#  [-7.97605896]]
# [[12.97720286]
#  [-7.98161669]]
# [[12.98409192]
#  [-7.98530089]]
# [[12.98869314]
#  [-7.98774298]]
# [[12.99176641]
#  [-7.98936159]]
# [[12.9938192 ]
#  [-7.99043428]]
# [[12.99519044]
#  [-7.99114506]]
# [[12.99610648]
#  [-7.99161593]]
# [[12.99671851]
#  [-7.99192775]]
# [[12.99712749]
#  [-7.99213416]]
# [[12.99740086]
#  [-7.99227068]]
# [[12.99758365]
#  [-7.99236088]]
# [[12.99770594]
#  [-7.99242038]]
# [[12.99778781]
# ...

# %% [markdown]
# ### Print weights and biases and see if we have worked correctly.

# %%
print(weights, biases)
# Out:
# [[12.99801251]
#  [-7.99245399]] [0.00823205]

# %% [markdown]
# ### Plot last outputs vs targets
# Since they are the last ones at the end of the training, they represent the final model accuracy. <br/>
# The closer this plot is to a 45 degree line, the closer target and output values are.

# %%
# We print the outputs and the targets in order to see if they have a linear relationship.
plt.plot(outputs,targets)
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()

# %%
outputs = np.dot(inputs,weights) + biases
print(outputs)
# Out:
# [[ 96.13021562]
#  [ 19.52887713]
#  [  8.4933269 ]
#  ...
#  [ -5.1303714 ]
#  [110.7427698 ]
#  [130.11002771]]

# %%
print(inputs.shape)
# Out:
# (10000, 2)

# %%
print(weights)
# Out:
# [[12.99801251]
#  [-7.99245399]]

# %%
outputs-targets
# Out:
# array([[-3.44684963],
#        [ 1.19011574],
#        [ 2.41693383],
#        ...,
#        [-4.21020948],
#        [ 1.55239571],
#        [ 3.74682627]])

# %%
#Shows the accuracy of our model
print((outputs[0]-targets[0])[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6920/2720767796.py in <module>
#       1 #Shows the accuracy of our model
# ----> 2 print((outputs[0]-targets[0])[0])
#
# NameError: name 'outputs' is not defined
